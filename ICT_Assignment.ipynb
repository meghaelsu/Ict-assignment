# %%
import pandas as pd

# %%
#Q 1

df = pd.read_excel('iris-1.xlsx')

# %%
#Q 2

print(df.to_string())
# Out:
#       SL   SW   PL   PW   Classification
# 0    5.1  3.5  1.4  0.2      Iris-setosa
# 1    4.9  3.0  1.4  0.2      Iris-setosa
# 2    4.7  3.2  1.3  0.2      Iris-setosa
# 3    4.6  3.1  1.5  0.2      Iris-setosa
# 4    5.0  3.6  1.4  0.2      Iris-setosa
# 5    5.4  3.9  1.7  0.4      Iris-setosa
# 6    4.6  3.4  1.4  0.3      Iris-setosa
# 7    5.0  3.4  1.5  0.2      Iris-setosa
# 8    4.4  2.9  1.4  0.2      Iris-setosa
# 9    4.9  3.1  1.5  0.1      Iris-setosa
# 10   5.4  3.7  1.5  0.2      Iris-setosa
# 11   4.8  3.4  1.6  0.2      Iris-setosa
# 12   4.8  3.0  1.4  0.1      Iris-setosa
# 13   4.3  3.0  1.1  0.1      Iris-setosa
# 14   5.8  4.0  1.2  0.2      Iris-setosa
# 15   5.7  4.4  1.5  0.4      Iris-setosa
# 16   5.4  3.9  1.3  0.4      Iris-setosa
# 17   5.1  3.5  1.4  0.3      Iris-setosa
# 18   5.7  3.8  1.7  0.3      Iris-setosa
# 19   5.1  3.8  1.5  0.3      Iris-setosa
# 20   5.4  3.4  1.7  0.2      Iris-setosa
# 21   5.1  3.7  1.5  0.4      Iris-setosa
# ...

# %%
#Q 3

print(df.mean())
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64
# <ipython-input-7-f98cceecb4a0>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.mean())

# %%
#Q 4

print(df.isnull().sum())
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
#Q 5

import matplotlib.pyplot as plt

# %%
#Q 5.1

plt.scatter(df['SL'], df['SW'], df['PL'], df['PW'])
plt.xlabel(' ')
plt.ylabel(' ')
plt.title('iris-1.xlsx')
plt.show()

# %%
#Q 5.2

plt.bar(df['SL'], df['SW'], df['PL'], df['PW'])
plt.xlabel(' ')
plt.ylabel(' ')
plt.title('iris-1.xlsx')
plt.show()

# %%
#Q 5.3

plt.plot(df['SL'], df['SW'], df['PL'], df['PW'])
plt.xlabel(' ')
plt.ylabel(' ')
plt.title('iris-1.xlsx')
plt.show()
